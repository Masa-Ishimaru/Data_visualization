# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
X = np.random.rand(10, 10)

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(X, annot = True, square = True, cmap = 'Spectral')
plt.ylim(len(X), 0)
plt.show()
